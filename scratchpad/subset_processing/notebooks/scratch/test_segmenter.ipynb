# %% [markdown]
# ## Segment a sparse 3D image with a single material component
#
# The goal of this notebook is to develop a 3D segmentation algorithm that improves segmentation where features are detected.
#
# **Data:** AM parts from Xuan Zhang.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import os
import h5py
import sys
import time
import seaborn as sns
import pandas as pd

# %%
history_path = '/home/atekawade/Dropbox/Arg/transfers/model_history'
descriptor_tag = 'tmp'#'test_noblanks_pt2cutoff_nostd'
model_names = {"segmenter" : "segmenter_Unet_%s"%descriptor_tag}

# %%
df = pd.read_csv(os.path.join(history_path, descriptor_tag, "stats.csv"))

# %%
sns.jointplot(data=df, x="SNR", y="IoU")

# %%
sns.jointplot(data=df, x="ystd", y="IoU")

# %%
sns.jointplot(data=df, x="void_frac", y="IoU")

# %%
sns.jointplot(data=df, x="ystd", y="IoU")
